# %%
import os

os.chdir('/content/drive/MyDrive/PANPP')
# !pip install -r requirement.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !sh train.sh
# Out:
# Epoch: [1 | 1]
# (1/9) LR: 0.010000 | Batch: 2.594s | Total: 0min | ETA: 0min | Loss: 1.509 | Loss(text/kernel/emb): 0.569/0.254/0.686 | IoU(text/kernel): 0.289/0.350

# %%
# !sh test.sh
# Out:
# reading type: cv2.
# Loading model and optimizer from checkpoint './checkpoints/cfg/checkpoint.pth.tar'
# Start testing 9 images
# Done!
